# %%
import os
import pandas as pd
import shutil

# Path to the HAM10000 dataset directory where all images are located
dataset_dir = 'DataSet\Combined'  

# Path to the Excel sheet containing image names and their types
excel_file = 'DataSet\HAM.csv'  # Update with the actual file name

# Load the Excel sheet into a Pandas DataFrame
df = pd.read_csv(excel_file)

# %%
for index, row in df.iterrows():
    image_name = row['image_id']  # Replace 'ImageName' with the actual column name in your Excel sheet
    image_type = row['dx']  # Replace 'Type' with the actual column name in your Excel sheet

    # Create a directory for the image type if it doesn't exist
    type_dir = os.path.join(dataset_dir, image_type)
    os.makedirs(type_dir, exist_ok=True)

    # Construct the source and destination paths
    source_path = os.path.join(dataset_dir, f'{image_name}.jpg')
    destination_path = os.path.join(type_dir,f'{image_name}.jpg')

    # Move the image to its respective folder
    shutil.move(source_path, destination_path)

print("Images have been organized into folders based on their types.")

# %%
import os
import shutil
import random

# Set the source directory where your dataset is located
source_dir = r'DataSet\Combined'
print(os.listdir(source_dir))

# Set the desired ratios (70:15:15)
train_ratio = 0.7
test_ratio = 0.15
val_ratio = 0.15

for skin_type in os.listdir(source_dir):
    skin_type_path = os.path.join(source_dir, skin_type)
    
    # List all images in the current subfolder
    images = os.listdir(skin_type_path)
    
    # Shuffle the images randomly
    random.shuffle(images)
    
    # Calculate the number of images for each split
    total_images = len(images)
    num_train = int(total_images * train_ratio)
    num_test = int(total_images * test_ratio)
    num_val = total_images - num_train - num_test
    
    # Create destination subdirectories for train, test, and validation
    train_skin_dir = os.path.join(skin_type_path, 'train')
    test_skin_dir = os.path.join(skin_type_path, 'test')
    val_skin_dir = os.path.join(skin_type_path, 'validation')
    
    os.makedirs(train_skin_dir, exist_ok=True)
    os.makedirs(test_skin_dir, exist_ok=True)
    os.makedirs(val_skin_dir, exist_ok=True)
    
    # Split the images and copy them to the respective directories
    train_images = images[:num_train]
    test_images = images[num_train:num_train+num_test]
    val_images = images[num_train+num_test:]
    
    for img in train_images:
        src_path = os.path.join(skin_type_path, img)
        dest_path = os.path.join(train_skin_dir, img)
        shutil.copy(src_path, dest_path)
    
    for img in test_images:
        src_path = os.path.join(skin_type_path, img)
        dest_path = os.path.join(test_skin_dir, img)
        shutil.copy(src_path, dest_path)
    
    for img in val_images:
        src_path = os.path.join(skin_type_path, img)
        dest_path = os.path.join(val_skin_dir, img)
        shutil.copy(src_path, dest_path)

print("Dataset split into train, test, and validation sets within each subfolder.")
# Out:
# ['image_0034321.png', 'image_0034322.png', 'image_0034323.png', 'image_0034324.png', 'image_0034325.png', 'image_0034326.png', 'image_0034327.png', 'image_0034328.png', 'image_0034329.png', 'image_0034330.png', 'image_0034331.png', 'image_0034332.png', 'image_0034333.png', 'image_0034334.png', 'image_0034335.png', 'image_0034336.png', 'image_0034337.png', 'image_0034338.png', 'image_0034339.png', 'image_0034340.png', 'image_0034341.png', 'image_0034342.png', 'image_0034343.png', 'image_0034344.png', 'image_0034345.png', 'image_0034346.png', 'image_0034347.png', 'image_0034348.png', 'image_0034349.png', 'image_0034350.png', 'image_0034351.png', 'image_0034352.png', 'image_0034353.png', 'image_0034354.png', 'image_0034355.png', 'image_0034356.png', 'image_0034357.png', 'image_0034358.png', 'image_0034359.png', 'image_0034360.png', 'image_0034361.png', 'image_0034362.png', 'image_0034363.png', 'image_0034364.png', 'image_0034365.png', 'image_0034366.png', 'image_0034367.png', 'image_0034368.png', 'image_0034369.png', 'image_0034370.png', 'image_0034371.png', 'image_0034372.png', 'image_0034373.png', 'image_0034374.png', 'image_0034375.png', 'image_0034376.png', 'image_0034377.png', 'image_0034378.png', 'image_0034379.png', 'image_0034380.png', 'image_0034381.png', 'image_0034382.png', 'image_0034383.png', 'image_0034384.png', 'image_0034385.png', 'image_0034386.png', 'image_0034387.png', 'image_0034388.png', 'image_0034389.png', 'image_0034390.png', 'image_0034391.png', 'image_0034392.png', 'image_0034393.png', 'image_0034394.png', 'image_0034395.png', 'image_0034396.png', 'image_0034397.png', 'image_0034398.png', 'image_0034399.png', 'image_0034400.png', 'image_0034401.png', 'image_0034402.png', 'image_0034403.png', 'image_0034404.png', 'image_0034405.png', 'image_0034406.png', 'image_0034407.png', 'image_0034408.png', 'image_0034409.png', 'image_0034410.png', 'image_0034411.png', 'image_0034412.png', 'image_0034413.png', 'image_0034414.png', 'image_0034415.png', 'image_0034416.png', 'image_0034417.png', 'image_0034418.png', 'image_0034419.png', 'image_0034420.png', 'image_0034421.png', 'image_0034422.png', 'image_0034423.png', 'image_0034424.png', 'image_0034425.png', 'image_0034426.png', 'image_0034427.png', 'image_0034428.png', 'image_0034429.png', 'image_0034430.png', 'image_0034431.png', 'image_0034432.png', 'image_0034433.png', 'image_0034434.png', 'image_0034435.png', 'image_0034436.png', 'image_0034437.png', 'image_0034438.png', 'image_0034439.png', 'image_0034440.png', 'image_0034441.png', 'image_0034442.png', 'image_0034443.png', 'image_0034444.png', 'image_0034445.png', 'image_0034446.png', 'image_0034447.png', 'image_0034448.png', 'image_0034449.png', 'image_0034450.png', 'image_0034451.png', 'image_0034452.png', 'image_0034453.png', 'image_0034454.png', 'image_0034455.png', 'image_0034456.png', 'image_0034457.png', 'image_0034458.png', 'image_0034459.png', 'image_0034460.png', 'image_0034461.png', 'image_0034462.png', 'image_0034463.png', 'image_0034464.png', 'image_0034465.png', 'image_0034466.png', 'image_0034467.png', 'image_0034468.png', 'image_0034469.png', 'image_0034470.png', 'image_0034471.png', 'image_0034472.png', 'image_0034473.png', 'image_0034474.png', 'image_0034475.png', 'image_0034476.png', 'image_0034477.png', 'image_0034478.png', 'image_0034479.png', 'image_0034480.png', 'image_0034481.png', 'image_0034482.png', 'image_0034483.png', 'image_0034484.png', 'image_0034485.png', 'image_0034486.png', 'image_0034487.png', 'image_0034488.png', 'image_0034489.png', 'image_0034490.png', 'image_0034491.png', 'image_0034492.png', 'image_0034493.png', 'image_0034494.png', 'image_0034495.png', 'image_0034496.png', 'image_0034497.png', 'image_0034498.png', 'image_0034499.png', 'image_0034500.png', 'image_0034501.png', 'image_0034502.png', 'image_0034503.png', 'image_0034504.png', 'image_0034505.png', 'image_0034506.png', 'image_0034507.png', 'image_0034508.png', 'image_0034509.png', 'image_0034510.png', 'image_00 ...
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[5], line 18
#      15 skin_type_path = os.path.join(source_dir, skin_type)
#      17 # List all images in the current subfolder
# ---> 18 images = os.listdir(skin_type_path)
#      20 # Shuffle the images randomly
#      21 random.shuffle(images)
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'DataSet\\Combined\\image_0034321.png'
